# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
#output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# generate random 500 latitude and longitude values
lat = np.random.uniform(low=-90, high=90, size=(1400,))
lon = np.random.uniform(low=-180, high=180, size=(1400,))

weather_df = pd.DataFrame({"Lat": lat,"Lon":lon})
weather_df["City"]=""
weather_df["Country Code"]=""
weather_df["Max Temp"]=""
weather_df["Humidity"]=""
weather_df["Cloudiness"]=""
weather_df["Wind Speed"]=""
weather_df.head()
# Out:
#          Lat         Lon City Country Code Max Temp Humidity Cloudiness  \
# 0  82.344153 -170.216084
# 1  60.525112 -143.781521
# 2  71.092499   91.801115
# 3 -62.652711  168.293416
# 4  43.310413   36.273274
#
#   Wind Speed
# 0
# 1
# 2
# 3
# 4

# %%
# Genearte cities list

for index,row in weather_df.iterrows():
    
    city = citipy.nearest_city(row['Lat'],row['Lon'])
    city_name = city.city_name
    city_country_code = city.country_code
    
    weather_df.set_value(index,"City",city_name)
    weather_df.set_value(index,"Country Code",city_country_code)
    
# creating a list of unique number of cities
# dropping the duplicates and keeping the first city name
weather_unique_df = weather_df.drop_duplicates(['City'], keep='first')

# number of unique cities in the list
len(weather_unique_df)
# Out:
# C:\Users\User\Anaconda3\envs\PythonData2\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if __name__ == '__main__':
# C:\Users\User\Anaconda3\envs\PythonData2\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.
# 608

# %%
# Perform API Calls

print('Beginning Data Retrieval')
print('-----------------------------')

for index,row in weather_unique_df.iterrows():
   
    print(f'Processing Record {index} | {row["City"]}')
    target_url = "http://api.openweathermap.org/data/2.5/weather?q=%s&units=IMPERIAL&APPID=%s" %(row["City"].replace(" ","+"), api_key)

    resp = requests.get(target_url).json()
 
    try:
        weather_unique_df.set_value(index,"Max Temp",resp["main"]["temp"])
        weather_unique_df.set_value(index,"Humidity",resp['main']['humidity'])
        weather_unique_df.set_value(index,"Cloudiness",resp['clouds']['all'])
        weather_unique_df.set_value(index,"Wind Speed",resp['wind']['speed'])
        
    except KeyError:
        print("oops !! missing values")
        
print("--------------------------")    
print("Data Retrieval Complete!")
print("--------------------------")
#weather_unique_df.head()
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0 | mys shmidta
# oops !! missing values
# Processing Record 1 | palmer
# C:\Users\User\Anaconda3\envs\PythonData2\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# C:\Users\User\Anaconda3\envs\PythonData2\lib\site-packages\ipykernel_launcher.py:15: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   from ipykernel import kernelapp as app
# C:\Users\User\Anaconda3\envs\PythonData2\lib\site-packages\ipykernel_launcher.py:16: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   app.launch_new_instance()
# C:\Users\User\Anaconda3\envs\PythonData2\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# Processing Record 2 | talnakh
# Processing Record 3 | bluff
# Processing Record 4 | sinop
# Processing Record 5 | pevek
# Processing Record 6 | albany
# Processing Record 7 | ushuaia
# Processing Record 8 | yanan
# oops !! missing values
# Processing Record 9 | vardo
# Processing Record 10 | upernavik
# Processing Record 11 | georgetown
# Processing Record 12 | half moon bay
# Processing Record 14 | mataura
# Processing Record 15 | astoria
# Processing Record 16 | chuy
# Processing Record 17 | yellowknife
# Processing Record 18 | namatanai
# Processing Record 19 | paramonga
# Processing Record 21 | gorzow wielkopolski
# Processing Record 23 | hami
# Processing Record 24 | matlock
# Processing Record 25 | bay roberts
# Processing Record 26 | attawapiskat
# oops !! missing values
# Processing Record 27 | iwanai
# Processing Record 28 | nizhneyansk
# oops !! missing values
# Processing Record 29 | sao filipe
# Processing Record 30 | puerto escondido
# Processing Record 32 | tura
# Processing Record 34 | hithadhoo
# Processing Record 36 | esperance
# Processing Record 37 | nowy dwor gdanski
# Processing Record 38 | butaritari
# Processing Record 39 | marcona
# oops !! missing values
# Processing Record 40 | rikitea
# Processing Record 42 | dikson
# Processing Record 43 | nouadhibou
# Processing Record 45 | morant bay
# Processing Record 46 | umm kaddadah
# Processing Record 48 | havelock
# Processing Record 49 | upata
# Processing Record 51 | busselton
# Processing Record 52 | sorland
# Processing Record 53 | kodiak
# Processing Record 54 | tautira
# Processing Record 55 | port alfred
# Processing Record 56 | avarua
# Processing Record 57 | fortuna
# Processing Record 58 | barrow
# Processing Record 59 | satitoa
# oops !! missing values
# Processing Record 63 | boa vista
# Processing Record 64 | palabuhanratu
# oops !! missing values
# Processing Record 67 | bethel
# Processing Record 68 | khatanga
# Processing Record 69 | illoqqortoormiut
# oops !! missing values
# Processing Record 70 | santa eulalia del rio
# oops !! missing values
# Processing Record 71 | grand river south east
# oops !! missing values
# Processing Record 72 | beyneu
# Processing Record 73 | san carlos de bariloche
# Processing Record 74 | saint-philippe
# Processing Record 75 | bengkulu
# oops !! missing values
# Processing Record 76 | lyuban
# Processing Record 78 | mahebourg
# Processing Record 79 | saint-augustin
# Processing Record 80 | marrakesh
# Processing Record 81 | carnarvon
# Processing Record 82 | sept-iles
# Processing Record 85 | hobart
# Processing Record 87 | saint anthony
# Processing Record 88 | khasan
# Processing Record 90 | saint-francois
# Processing Record 91 | nabire
# Processing Record 92 | yumen
# Processing Record 93 | castel san giovanni
# Processing Record 95 | hilo
# Processing Record 96 | labuhan
# Processing Record 97 | bredasdorp
# Processing Record 99 | ilulissat
# Processing Record 100 | belushya guba
# oops !! missing values
# Processing Record 101 | punta arenas
# Processing Record 103 | saldanha
# Processing Record 104 | tiksi
# Processing Record 105 | atuona
# Processing Record 107 | altagracia de orituco
# Processing Record 108 | norsup
# Processing Record 109 | narsaq
# Processing Record 110 | bambous virieux
# Processing Record 112 | kure
# Processing Record 114 | chokurdakh
# Processing Record 116 | jamestown
# Processing Record 117 | samfya
# Processing Record 119 | beidao
# Processing Record 122 | adrar
# Processing Record 123 | gualaquiza
# Processing Record 125 | lago da pedra
# oops !! missing values
# Processing Record 127 | luderitz
# Processing Record 128 | torbay
# Processing Record 129 | mocuba
# Processing Record 131 | sitka
# Processing Record 132 | loukhi
# Processing Record 134 | alenquer
# Processing Record 136 | tarbagatay
# Processing Record 138 | akyab
# oops !! missing values
# Processing Record 140 | rawson
# Processing Record 142 | cape town
# Processing Record 143 | lloydminster
# Processing Record 144 | saskylakh
# Processing Record 147 | hovd
# Processing Record 148 | gemena
# Processing Record 150 | selikhino
# Processing Record 151 | klaksvik
# Processing Record 152 | sentyabrskiy
# oops !! missing values
# Processing Record 154 | santa fe
# Processing Record 155 | walvis bay
# Processing Record 156 | qaanaaq
# Processing Record 158 | ambon
# Processing Record 159 | evans
# Processing Record 160 | atar
# Processing Record 161 | maceio
# Processing Record 163 | puerto ayora
# Processing Record 164 | dwarka
# Processing Record 165 | birecik
# Processing Record 166 | arinos
# Processing Record 167 | deputatskiy
# Processing Record 170 | lixourion
# Processing Record 171 | umzimvubu
# oops !! missing values
# Processing Record 173 | nanortalik
# Processing Record 174 | tramore
# Processing Record 175 | santa cruz cabralia
# Processing Record 176 | broome
# Processing Record 177 | venice
# Processing Record 178 | shenjiamen
# Processing Record 180 | necochea
# Processing Record 181 | victoria
# Processing Record 184 | souillac
# Processing Record 185 | hermanus
# Processing Record 190 | taolanaro
# oops !! missing values
# Processing Record 195 | vaini
# Processing Record 196 | jucurutu
# Processing Record 198 | clyde river
# Processing Record 200 | inuvik
# Processing Record 203 | hasaki
# Processing Record 204 | naze
# Processing Record 206 | sechura
# Processing Record 209 | josanicka banja
# Processing Record 212 | tsihombe
# oops !! missing values
# Processing Record 218 | cayenne
# Processing Record 219 | kavieng
# Processing Record 222 | faya
# Processing Record 224 | budeasa
# oops !! missing values
# Processing Record 227 | port hedland
# Processing Record 228 | goose creek
# Processing Record 234 | pangai
# Processing Record 235 | chernaya kholunitsa
# Processing Record 237 | lodja
# Processing Record 239 | le mans
# Processing Record 245 | thompson
# Processing Record 246 | castro
# Processing Record 248 | surab
# Processing Record 249 | puerto rondon
# Processing Record 250 | arraial do cabo
# Processing Record 252 | tuktoyaktuk
# Processing Record 253 | severo-kurilsk
# Processing Record 254 | tucurui
# Processing Record 255 | vanimo
# Processing Record 256 | san patricio
# Processing Record 257 | rorvik
# Processing Record 260 | maghama
# oops !! missing values
# Processing Record 264 | faanui
# Processing Record 266 | poum
# Processing Record 268 | tuatapere
# Processing Record 269 | saint george
# Processing Record 270 | vengerovo
# Processing Record 271 | carauari
# Processing Record 272 | okhotsk
# Processing Record 273 | flinders
# Processing Record 274 | lata
# Processing Record 275 | lampa
# Processing Record 278 | lebu
# Processing Record 279 | kalengwa
# Processing Record 280 | padre paraiso
# Processing Record 281 | port elizabeth
# Processing Record 284 | marawi
# Processing Record 286 | lensk
# Processing Record 287 | berlin
# Processing Record 288 | port blair
# Processing Record 291 | kirovskiy
# Processing Record 296 | guerrero negro
# Processing Record 297 | fairbanks
# Processing Record 298 | anito
# Processing Record 300 | tanjong sepat
# oops !! missing values
# Processing Record 307 | jackson
# Processing Record 309 | naryan-mar
# Processing Record 313 | ust-ordynskiy
# Processing Record 314 | jha jha
# Processing Record 318 | alofi
# Processing Record 320 | ganzhou
# Processing Record 323 | saint-joseph
# Processing Record 325 | codrington
# Processing Record 327 | chagda
# oops !! missing values
# Processing Record 329 | minot
# Processing Record 330 | high level
# Processing Record 331 | wanning
# Processing Record 332 | turukhansk
# Processing Record 336 | kapaa
# Processing Record 337 | margate
# Processing Record 338 | paamiut
# Processing Record 340 | tiarei
# Processing Record 343 | winnemucca
# Processing Record 347 | ancud
# Processing Record 349 | kamenskoye
# oops !! missing values
# Processing Record 350 | tomatlan
# Processing Record 356 | sorong
# Processing Record 359 | nazareno
# Processing Record 361 | kiama
# Processing Record 362 | dudinka
# Processing Record 363 | suntar
# Processing Record 366 | nalut
# Processing Record 367 | amderma
# oops !! missing values
# Processing Record 370 | grayvoron
# Processing Record 372 | assens
# Processing Record 378 | mandalgovi
# Processing Record 379 | new norfolk
# Processing Record 380 | palu
# Processing Record 382 | kalmunai
# Processing Record 383 | polunochnoye
# Processing Record 385 | maracacume
# Processing Record 389 | tambovka
# Processing Record 390 | valparaiso
# Processing Record 392 | east london
# Processing Record 393 | lilongwe
# Processing Record 394 | mananara
# oops !! missing values
# Processing Record 395 | arawa
# Processing Record 396 | lasa
# Processing Record 400 | porto belo
# Processing Record 402 | minanga
# Processing Record 404 | payakumbuh
# Processing Record 406 | ambilobe
# Processing Record 410 | canaries
# oops !! missing values
# Processing Record 412 | karasjok
# Processing Record 413 | osmena
# Processing Record 414 | cherskiy
# Processing Record 415 | barentsburg
# oops !! missing values
# Processing Record 416 | harvard
# Processing Record 418 | sangar
# Processing Record 419 | svetlyy
# oops !! missing values
# Processing Record 420 | skibbereen
# Processing Record 423 | westport
# Processing Record 424 | itarema
# Processing Record 425 | rembang
# Processing Record 426 | cap malheureux
# Processing Record 428 | cabedelo
# Processing Record 429 | vaitupu
# oops !! missing values
# Processing Record 430 | orgun
# oops !! missing values
# Processing Record 432 | yar-sale
# Processing Record 435 | ostrovnoy
# Processing Record 436 | green valley
# Processing Record 438 | rungata
# oops !! missing values
# Processing Record 439 | cabra
# Processing Record 441 | lyubech
# Processing Record 442 | bubaque
# Processing Record 443 | lagos
# Processing Record 444 | agirish
# Processing Record 446 | charters towers
# Processing Record 450 | sioux lookout
# Processing Record 451 | seoul
# Processing Record 455 | uarini
# Processing Record 456 | kapoeta
# oops !! missing values
# Processing Record 458 | gornopravdinsk
# Processing Record 459 | nikolskoye
# Processing Record 461 | pirovskoye
# Processing Record 464 | lakatoro
# Processing Record 466 | nueva guinea
# Processing Record 468 | rocha
# Processing Record 470 | abu dhabi
# Processing Record 472 | emerald
# Processing Record 473 | havre-saint-pierre
# Processing Record 474 | tabory
# Processing Record 475 | gamba
# Processing Record 476 | buzmeyin
# Processing Record 480 | longyearbyen
# Processing Record 481 | aden
# Processing Record 486 | martapura
# Processing Record 487 | galle
# Processing Record 488 | bilma
# Processing Record 490 | imbituba
# Processing Record 491 | vestmanna
# Processing Record 493 | ponta do sol
# Processing Record 494 | vega de alatorre
# Processing Record 496 | flin flon
# Processing Record 498 | nara
# Processing Record 501 | celestun
# Processing Record 505 | santa maria
# Processing Record 506 | sorsk
# Processing Record 509 | haines junction
# Processing Record 511 | loandjili
# Processing Record 513 | vaitape
# Processing Record 514 | isiro
# Processing Record 515 | jega
# Processing Record 516 | belmonte
# Processing Record 517 | hamilton
# Processing Record 519 | artyk
# oops !! missing values
# Processing Record 520 | lorengau
# Processing Record 525 | beringovskiy
# Processing Record 526 | kharp
# Processing Record 527 | mar del plata
# Processing Record 529 | whitehorse
# Processing Record 532 | sabang
# Processing Record 533 | oksfjord
# Processing Record 535 | ituni
# oops !! missing values
# Processing Record 540 | vila
# Processing Record 548 | griffith
# Processing Record 551 | lavrentiya
# Processing Record 552 | poya
# Processing Record 553 | los llanos de aridane
# Processing Record 555 | nuuk
# Processing Record 557 | yerbogachen
# Processing Record 561 | bumba
# Processing Record 566 | tiznit
# Processing Record 567 | caravelas
# Processing Record 571 | peterhead
# Processing Record 572 | la ronge
# Processing Record 573 | raudeberg
# Processing Record 575 | smolenka
# Processing Record 581 | bargal
# oops !! missing values
# Processing Record 582 | areka
# Processing Record 584 | aalen
# Processing Record 587 | saleaula
# oops !! missing values
# Processing Record 588 | leningradskiy
# Processing Record 597 | henties bay
# Processing Record 598 | beloha
# Processing Record 600 | nisia floresta
# Processing Record 601 | la palma
# Processing Record 603 | sao felix do xingu
# Processing Record 604 | beroroha
# Processing Record 605 | kholodnyy
# Processing Record 608 | linhares
# Processing Record 609 | kegayli
# oops !! missing values
# Processing Record 611 | salalah
# Processing Record 615 | tasiilaq
# Processing Record 617 | alyangula
# Processing Record 621 | mahon
# Processing Record 622 | arona
# Processing Record 623 | itatinga
# Processing Record 624 | sanmenxia
# Processing Record 626 | sao joao da barra
# Processing Record 629 | geraldton
# Processing Record 630 | aloleng
# Processing Record 633 | capoterra
# Processing Record 637 | campoverde
# Processing Record 638 | montepuez
# Processing Record 639 | simao
# Processing Record 641 | along
# Processing Record 642 | zhezkazgan
# Processing Record 643 | upington
# Processing Record 655 | quepos
# Processing Record 667 | luoyang
# Processing Record 674 | iskateley
# Processing Record 677 | toliary
# oops !! missing values
# Processing Record 680 | petropavlovsk-kamchatskiy
# Processing Record 683 | fort-shevchenko
# Processing Record 684 | sassandra
# Processing Record 686 | kavaratti
# Processing Record 691 | port lincoln
# Processing Record 692 | mae ramat
# Processing Record 693 | san luis
# Processing Record 697 | miri
# Processing Record 699 | ribeira grande
# Processing Record 700 | nisporeni
# Processing Record 702 | haimen
# Processing Record 705 | oranjemund
# Processing Record 706 | kahului
# Processing Record 709 | shitanjing
# Processing Record 711 | lac du bonnet
# Processing Record 717 | emirdag
# Processing Record 719 | chaumont
# Processing Record 720 | provideniya
# Processing Record 722 | xuddur
# Processing Record 728 | glazov
# Processing Record 735 | wanaka
# Processing Record 736 | kollam
# Processing Record 748 | lagoa
# Processing Record 750 | tarudant
# oops !! missing values
# Processing Record 752 | sao jose da coroa grande
# Processing Record 756 | muisne
# Processing Record 757 | banda aceh
# Processing Record 758 | corinto
# Processing Record 759 | smithers
# Processing Record 760 | nurota
# Processing Record 762 | khovu-aksy
# Processing Record 763 | meyungs
# oops !! missing values
# Processing Record 766 | chaa-khol
# oops !! missing values
# Processing Record 767 | meulaboh
# Processing Record 768 | viet tri
# Processing Record 770 | gigmoto
# Processing Record 772 | bathsheba
# Processing Record 774 | chalus
# Processing Record 775 | roald
# Processing Record 778 | lakes entrance
# Processing Record 779 | vostok
# Processing Record 780 | gilbues
# Processing Record 784 | rio grande
# Processing Record 795 | dhangadhi
# Processing Record 796 | ejura
# Processing Record 798 | zapote
# Processing Record 800 | rabak
# Processing Record 807 | greenfield
# Processing Record 808 | perth
# Processing Record 813 | havoysund
# Processing Record 816 | rosarito
# Processing Record 817 | calvinia
# Processing Record 820 | chabua
# Processing Record 822 | katsuura
# Processing Record 826 | morro bay
# Processing Record 830 | verkhoyansk
# Processing Record 833 | madang
# Processing Record 836 | san ramon
# Processing Record 838 | constitucion
# Processing Record 839 | malibu
# Processing Record 846 | manfredonia
# Processing Record 849 | ormara
# Processing Record 851 | grindavik
# Processing Record 852 | taltal
# Processing Record 858 | langgons
# Processing Record 865 | san quintin
# Processing Record 866 | eyl
# Processing Record 870 | nantucket
# Processing Record 872 | lazaro cardenas
# Processing Record 876 | araguatins
# oops !! missing values
# Processing Record 878 | mabaruma
# Processing Record 879 | tupiza
# Processing Record 881 | macaboboni
# oops !! missing values
# Processing Record 886 | hofn
# Processing Record 889 | amga
# Processing Record 893 | waipawa
# Processing Record 894 | namibe
# Processing Record 895 | quatre cocos
# Processing Record 897 | nichinan
# Processing Record 898 | caorle
# Processing Record 901 | oranjestad
# Processing Record 906 | terra santa
# Processing Record 908 | nizwa
# Processing Record 909 | kharhial
# Processing Record 912 | kirksville
# Processing Record 913 | adeje
# Processing Record 916 | taksimo
# Processing Record 917 | sibolga
# Processing Record 918 | muros
# Processing Record 921 | monchegorsk
# Processing Record 923 | pierre
# Processing Record 928 | senneterre
# Processing Record 930 | zhangjiakou
# Processing Record 931 | vila franca do campo
# Processing Record 932 | pirenopolis
# Processing Record 933 | boende
# Processing Record 934 | sembakung
# Processing Record 937 | monduli
# Processing Record 943 | sayyan
# Processing Record 946 | jabinyanah
# Processing Record 948 | sinnamary
# Processing Record 954 | shimoda
# Processing Record 955 | santa cruz de tenerife
# Processing Record 958 | axim
# Processing Record 960 | pangnirtung
# Processing Record 963 | airai
# Processing Record 968 | korla
# oops !! missing values
# Processing Record 969 | college
# Processing Record 974 | ponta delgada
# Processing Record 977 | tual
# Processing Record 978 | antalaha
# Processing Record 980 | moose factory
# Processing Record 981 | kuche
# oops !! missing values
# Processing Record 983 | elizabeth city
# Processing Record 985 | ouargaye
# Processing Record 991 | kapit
# Processing Record 992 | padang
# Processing Record 993 | jinchang
# Processing Record 994 | castanos
# Processing Record 997 | san rafael
# Processing Record 1004 | pyapon
# Processing Record 1005 | santiago de cao
# Processing Record 1010 | barbar
# oops !! missing values
# Processing Record 1011 | coihaique
# Processing Record 1015 | chicago
# Processing Record 1019 | dicabisagan
# Processing Record 1025 | uhlove
# Processing Record 1031 | touros
# Processing Record 1034 | dingle
# Processing Record 1042 | chitral
# Processing Record 1048 | karamea
# oops !! missing values
# Processing Record 1053 | norman wells
# Processing Record 1057 | slantsy
# Processing Record 1066 | tagusao
# Processing Record 1067 | sarangani
# Processing Record 1072 | altay
# Processing Record 1075 | vila velha
# Processing Record 1077 | bintulu
# Processing Record 1079 | skagen
# Processing Record 1080 | bud
# Processing Record 1084 | balikpapan
# Processing Record 1086 | douglas
# Processing Record 1089 | bure
# Processing Record 1091 | sabla
# Processing Record 1092 | kinablangan
# Processing Record 1096 | dunedin
# Processing Record 1097 | tecate
# Processing Record 1099 | ambatondrazaka
# Processing Record 1108 | te anau
# Processing Record 1109 | yakeshi
# Processing Record 1112 | asau
# oops !! missing values
# Processing Record 1125 | rayachoti
# Processing Record 1129 | pandan
# Processing Record 1132 | hajnowka
# Processing Record 1136 | shambu
# Processing Record 1142 | soyo
# Processing Record 1143 | baykit
# Processing Record 1145 | macamic
# Processing Record 1147 | dambulla
# Processing Record 1149 | gaurnadi
# Processing Record 1151 | jalu
# Processing Record 1152 | cascais
# Processing Record 1156 | gillette
# Processing Record 1158 | seydi
# Processing Record 1161 | krasnoselkup
# oops !! missing values
# Processing Record 1167 | lompoc
# Processing Record 1168 | helong
# Processing Record 1171 | sri aman
# Processing Record 1173 | silver city
# Processing Record 1177 | srednekolymsk
# Processing Record 1178 | volcan
# Processing Record 1181 | mitsamiouli
# Processing Record 1182 | coos bay
# Processing Record 1183 | kokstad
# Processing Record 1187 | santa cruz
# Processing Record 1188 | ambodifototra
# oops !! missing values
# Processing Record 1191 | beira
# Processing Record 1192 | warrington
# Processing Record 1194 | sobolevo
# Processing Record 1200 | kozhva
# Processing Record 1204 | camacha
# Processing Record 1206 | ati
# Processing Record 1207 | skalistyy
# oops !! missing values
# Processing Record 1208 | nosy varika
# Processing Record 1211 | ekhabi
# Processing Record 1214 | mehamn
# Processing Record 1215 | panguna
# Processing Record 1222 | distraccion
# Processing Record 1223 | zhangye
# Processing Record 1225 | andra
# Processing Record 1227 | port hardy
# Processing Record 1234 | makakilo city
# Processing Record 1235 | alihe
# Processing Record 1236 | kaitangata
# Processing Record 1237 | pisco
# Processing Record 1240 | safaga
# oops !! missing values
# Processing Record 1241 | devils lake
# Processing Record 1242 | narwar
# Processing Record 1243 | pathardi
# Processing Record 1244 | ukiah
# Processing Record 1245 | shache
# Processing Record 1250 | manitowoc
# Processing Record 1253 | ambulu
# Processing Record 1259 | kyabe
# Processing Record 1260 | ust-kuyga
# Processing Record 1264 | plouzane
# Processing Record 1265 | olinda
# Processing Record 1267 | mount gambier
# Processing Record 1272 | uray
# Processing Record 1274 | cabo san lucas
# Processing Record 1279 | cavalcante
# Processing Record 1280 | matara
# Processing Record 1282 | verkhnyaya toyma
# Processing Record 1284 | tongliao
# Processing Record 1285 | bull savanna
# Processing Record 1289 | zaysan
# Processing Record 1291 | longhua
# Processing Record 1294 | kesennuma
# oops !! missing values
# Processing Record 1299 | matina
# Processing Record 1302 | oda
# Processing Record 1304 | novaya bryan
# Processing Record 1306 | kaura namoda
# Processing Record 1308 | umm lajj
# Processing Record 1309 | fort nelson
# Processing Record 1314 | hambantota
# Processing Record 1315 | pemba
# Processing Record 1318 | manokwari
# Processing Record 1320 | cosala
# oops !! missing values
# Processing Record 1321 | karakendzha
# oops !! missing values
# Processing Record 1325 | ziro
# Processing Record 1328 | stony plain
# Processing Record 1335 | concepcion del uruguay
# Processing Record 1343 | razole
# Processing Record 1348 | kamenka
# Processing Record 1352 | cam ranh
# Processing Record 1353 | kabanjahe
# Processing Record 1354 | cotonou
# Processing Record 1357 | spearfish
# Processing Record 1361 | pacific grove
# Processing Record 1364 | pumiao
# Processing Record 1365 | cumra
# Processing Record 1369 | karpogory
# Processing Record 1378 | thinadhoo
# Processing Record 1388 | tanjong malim
# oops !! missing values
# Processing Record 1389 | anisoc
# Processing Record 1390 | gat
# Processing Record 1391 | portland
# Processing Record 1392 | angul
# Processing Record 1394 | jablah
# --------------------------
# Data Retrieval Complete!
# --------------------------

# %%
#replacing the empty spaces with NaN values
weather_clean_df = weather_unique_df.replace(r'\s+', np.nan).replace('',np.nan)

# %%
# Dropping the rows with NaN values
weather_clean_df = weather_clean_df.dropna(how='any')
weather_clean_df = weather_clean_df.round({"Lat":2,"Lon":2})
weather_clean_df.reset_index()
#  display the dataframe with retrieved Data

weather_clean_df.to_csv('weatherAPI.csv',index=False)
weather_clean_df.head()
# Out:
#      Lat     Lon     City Country Code  Max Temp  Humidity  Cloudiness  \
# 1  60.53 -143.78   palmer           us     57.24      72.0        75.0
# 2  71.09   91.80  talnakh           ru     31.85      96.0        88.0
# 3 -62.65  168.29    bluff           nz     74.15      92.0         0.0
# 4  43.31   36.27    sinop           tr     48.06      49.0        75.0
# 5  81.98  167.76    pevek           ru     -0.82      78.0        56.0
#
#    Wind Speed
# 1       18.34
# 2       17.05
# 3        2.39
# 4       13.87
# 5        1.72

# %%
# making sure, we have 500+ cities in our data frame
weather_clean_df.count()
# Out:
# Lat             608
# Lon             608
# City            608
# Country Code    608
# Max Temp        552
# Humidity        552
# Cloudiness      552
# Wind Speed      552
# dtype: int64

# %%
#scatter plots
#Latitude vs Temperature PLot

Lat = weather_clean_df["Lat"].tolist()
temp = weather_clean_df["Max Temp"].tolist()

# enlarging the size of the plot and setting grid lines
fig = plt.figure(figsize=(10,8))
plt.grid(True)
plt.scatter(x=Lat,y=temp,marker="o",facecolors="blue",edgecolors='black')

plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.title(f"Latitude Vs Max Temp({datetime.now().strftime('%m/%d/%Y %H:%M')})")
fig.savefig('Max_Temp.png', dpi=fig.dpi)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-4ada0cde1b3f> in <module>
#      12 plt.xlabel("Latitude")
#      13 plt.ylabel("Max Temp (F)")
# ---> 14 plt.title(f"Latitude Vs Max Temp({datetime.now().strftime('%m/%d/%Y %H:%M')})")
#      15 fig.savefig('Max_Temp.png', dpi=fig.dpi)
#      16
#
# NameError: name 'datetime' is not defined

# %%
#Latitude Vs Humidity PLot

Lat = weather_clean_df["Lat"].tolist()
hum = weather_clean_df["Humidity"].tolist()

# enlarging the size of the plot and setting grid lines
fig = plt.figure(figsize=(10,8))
plt.grid(True)
plt.scatter(x=Lat,y=hum,marker="o",facecolors="blue",edgecolors='black')

plt.title(f"Latitude Vs Humidity ({datetime.now().strftime('%m/%d/%Y %H:%M')})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
fig.savefig('humidity.png', dpi=fig.dpi)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-3a0b2f025989> in <module>
#       9 plt.scatter(x=Lat,y=hum,marker="o",facecolors="blue",edgecolors='black')
#      10
# ---> 11 plt.title(f"Latitude Vs Humidity ({datetime.now().strftime('%m/%d/%Y %H:%M')})")
#      12 plt.xlabel("Latitude")
#      13 plt.ylabel("Humidity (%)")
#
# NameError: name 'datetime' is not defined

# %%
#Latitude Vs Cloudiness Plot

Lat = weather_clean_df["Lat"].tolist()
cloud = weather_clean_df["Cloudiness"].tolist()

# enlarging the size of the plot and setting grid lines
fig = plt.figure(figsize=(10,8))
plt.grid(True)
plt.scatter(x=Lat,y=cloud,marker="o",facecolors="blue",edgecolors='black')

plt.title(f"Latitude Vs Cloudiness ({datetime.now().strftime('%m/%d/%Y %H:%M')})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
fig.savefig('cloudy.png', dpi=fig.dpi)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-c08886d22104> in <module>
#       9 plt.scatter(x=Lat,y=cloud,marker="o",facecolors="blue",edgecolors='black')
#      10
# ---> 11 plt.title(f"Latitude Vs Cloudiness ({datetime.now().strftime('%m/%d/%Y %H:%M')})")
#      12 plt.xlabel("Latitude")
#      13 plt.ylabel("Cloudiness (%)")
#
# NameError: name 'datetime' is not defined

# %%
#Latitude vs Wind Speed plot

Lat = weather_clean_df["Lat"].tolist()
wind = weather_clean_df["Wind Speed"].tolist()

# enlarging the size of the plot and setting grid lines
fig = plt.figure(figsize=(10,8))
plt.grid(True)
plt.scatter(x=Lat,y=wind,marker="o",facecolors="blue",edgecolors='black')

plt.title(f"Latitude Vs Wind Speed ")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
fig.savefig('wind_speed.png', dpi=fig.dpi)

plt.show()
